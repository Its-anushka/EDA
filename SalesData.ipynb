# %% [markdown]
# <a href="https://colab.research.google.com/github/Its-anushka/EDA/blob/main/SalesData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Sample data.xlsx")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
# 9994           Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# We have a dataset with missing values, inconsistent formats, and outliers. The goal is to clean the data, handle missing values, standardize formats, and remove outliers.

# %% [markdown]
# Handle Missing Values:

# %%
df.isnull().sum()
# Out:
# Ship Mode          0
# Segment            0
# Country            0
# City               0
# State              0
# Postal Code        0
# Region             0
# Category           1
# Sub-Category       1
# Sales              0
# Quantity           1
# Discount        4799
# Profit             1
# dtype: int64

# %%
df[df['Category'].isnull()]
# Out:
#      Ship Mode   Segment        Country         City       State  Postal Code  \
# 9994     Class  Consumer  United States  Westminster  California        92683
#
#      Region Category Sub-Category   Sales  Quantity  Discount  Profit
# 9994   West      NaN          NaN  243.16       NaN       NaN     NaN

# %%
df[df['Sub-Category'].isnull()]
# Out:
#      Ship Mode   Segment        Country         City       State  Postal Code  \
# 9994     Class  Consumer  United States  Westminster  California        92683
#
#      Region Category Sub-Category   Sales  Quantity  Discount  Profit
# 9994   West      NaN          NaN  243.16       NaN       NaN     NaN

# %%
df[df['Quantity'].isnull()]
# Out:
#      Ship Mode   Segment        Country         City       State  Postal Code  \
# 9994     Class  Consumer  United States  Westminster  California        92683
#
#      Region Category Sub-Category   Sales  Quantity  Discount  Profit
# 9994   West      NaN          NaN  243.16       NaN       NaN     NaN

# %%
df[df['Discount'].isnull()]
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 0       Second Class   Consumer  United States    Henderson    Kentucky
# 1       Second Class   Consumer  United States    Henderson    Kentucky
# 2       Second Class  Corporate  United States  Los Angeles  California
# 5     Standard Class   Consumer  United States  Los Angeles  California
# 6     Standard Class   Consumer  United States  Los Angeles  California
# ...              ...        ...            ...          ...         ...
# 9988  Standard Class  Corporate  United States       Athens     Georgia
# 9990  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
# 9994           Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category   Sales  Quantity  \
# ...

# %%
df['Discount'].fillna(0, inplace = True)

# %%
df[df['Profit'].isnull()]
# Out:
#      Ship Mode   Segment        Country         City       State  Postal Code  \
# 9994     Class  Consumer  United States  Westminster  California        92683
#
#      Region Category Sub-Category   Sales  Quantity  Discount  Profit
# 9994   West      NaN          NaN  243.16       NaN       NaN     NaN

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# To replace with mean/median
#
#
# *   df[col].fillna(df[col].median()/mean(),  inplace=True)

# %%
sns.histplot(df['Quantity'])
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
# Example:
Correlation heatmap correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

# %%
sns.pairplot(df)

# %%
df.columns.str.lower()

df.columns.str.replace(' ', '_')

df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600       2.0
# 1        42420  South        Furniture       Chairs  731.9400       3.0
# 2        90036   West  Office Supplies       Labels   14.6200       2.0
# 3        33311  South        Furniture       Tables  957.5775       5.0
# 4        33311  South  Office Supplies      Storage   22.3680       2.0
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
# Example: Remove outliers from 'age' column
z_scores = (df['age'] - df['age'].mean()) / df['age'].std()
df_cleaned = df[abs(z_scores) < 3] # Keep data within 3 standard deviations
df_cleaned.to_csv('cleaned_data.csv', index=False)

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Profit'], bins = 15)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Profit', y='Sales', data=df)
sns.regplot(x="Profit", y="Sales", data=df)
plt.title('Relationship between Profit and Sales')
plt.xlabel('Profit')
plt.ylabel('Sales')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Category', data=df)
plt.title('Category')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['Category'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Category')
plt.show()

# %%
plt.figure(figsize=(8, 6))
df['Category'].value_counts().plot(kind='bar')
plt.title('Category')
plt.show()
